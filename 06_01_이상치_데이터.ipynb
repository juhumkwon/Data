# %% [markdown]
# <a href="https://colab.research.google.com/github/juhumkwon/Data/blob/main/06_01_%EC%9D%B4%EC%83%81%EC%B9%98_%EB%8D%B0%EC%9D%B4%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# 정상적인 네트워크 활동 데이터 (클러스터 형태)
normal_data = np.random.multivariate_normal([50, 500], [[50, 0], [0, 5000]], size=200)

# 이상치 데이터 추가 (비정상적인 활동)
outliers = np.random.uniform(
    low=[100, 1000],  # x = (100 ~ 150)
    high=[150, 2000], # y = (1000 ~ 2000)
    size=(10, 2)      # 10개의 샘플생성
)

plt.scatter(normal_data[:, 0], normal_data[:, 1], label='Normal', alpha=0.6)
plt.scatter(outliers[:, 0], outliers[:, 1], color='red', marker='x', label='Outliers')
plt.legend()
plt.title("Normal Data vs. Outliers")
plt.xlabel("Feature 1 (e.g., data size)")
plt.ylabel("Feature 2 (e.g., connection time)")
plt.show()

# %%
import numpy as np

# Generate some sample data for demonstration
np.random.seed(42) # for reproducibility
normal_data = np.random.randn(100, 2) # 100 data points with 2 features
outliers = np.random.uniform(low=-10, high=10, size=(10, 2)) # 10 outliers
